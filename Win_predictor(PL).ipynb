# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv",index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result  gf  ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L   0   1
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W   5   0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W   5   0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W   1   0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D   0   0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  17.3  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  18.5  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.8  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.3  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  16.4  1.0  0.0   0.0
#
#    season             team
# 1    2023  Manchester City
# 2    2023  Manchester City
# 3    2023  Manchester City
# 4    2023  Manchester City
# 6    2023  Manchester City
#
# [5 rows x 27 columns]

# %%
matches.shape
# Out:
# (3800, 27)

# %%
38*20*5
# Out:
# 3800

# %%
matches["team"].value_counts()
# Out:
# Manchester City             190
# Brighton and Hove Albion    190
# Burnley                     190
# Everton                     190
# Liverpool                   190
# Crystal Palace              190
# Newcastle United            190
# Southampton                 190
# Leicester City              190
# Tottenham Hotspur           190
# West Ham United             190
# Manchester United           190
# Chelsea                     190
# Arsenal                     190
# Wolverhampton Wanderers     152
# Watford                     152
# Aston Villa                 114
# Bournemouth                 114
# Leeds United                 76
# Norwich City                 76
# Fulham                       76
# West Bromwich Albion         76
# Sheffield United             76
# Huddersfield Town            76
# Brentford                    38
# Cardiff City                 38
# Swansea City                 38
# Stoke City                   38
# Name: team, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     100
# Matchweek 29    100
# Matchweek 22    100
# Matchweek 23    100
# Matchweek 24    100
# Matchweek 25    100
# Matchweek 26    100
# Matchweek 27    100
# Matchweek 28    100
# Matchweek 31    100
# Matchweek 2     100
# Matchweek 32    100
# Matchweek 30    100
# Matchweek 34    100
# Matchweek 35    100
# Matchweek 36    100
# Matchweek 33    100
# Matchweek 37    100
# Matchweek 21    100
# Matchweek 20    100
# Matchweek 19    100
# Matchweek 18    100
# Matchweek 3     100
# Matchweek 4     100
# Matchweek 5     100
# Matchweek 6     100
# Matchweek 7     100
# Matchweek 8     100
# Matchweek 9     100
# Matchweek 10    100
# Matchweek 11    100
# Matchweek 12    100
# Matchweek 13    100
# Matchweek 14    100
# Matchweek 15    100
# Matchweek 16    100
# Matchweek 17    100
# Matchweek 38    100
# Name: round, dtype: int64

# %%
 matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches.dtypes
# Out:
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                       int64
# ga                       int64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L   0   1
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W   5   0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W   5   0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W   1   0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D   0   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 38 2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W   1   0
# 39 2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D   2   2
# 40 2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W   1   0
# 41 2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W   1   0
# 42 2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L   0   2
#
#           opponent  ...    sh   sot  dist   fk   pk pkatt season  \
# 1        Tottenham  ...  18.0   4.0  17.3  1.0  0.0   0.0   2023
# 2     Norwich City  ...  16.0   4.0  18.5  1.0  0.0   0.0   2023
# 3          Arsenal  ...  25.0  10.0  14.8  0.0  0.0   0.0   2023
# 4   Leicester City  ...  25.0   8.0  14.3  0.0  0.0   0.0   2023
# 6      Southampton  ...  16.0   1.0  16.4  1.0  0.0   0.0   2023
# ..             ...  ...   ...   ...   ...  ...  ...   ...    ...
# 38  Manchester Utd  ...  10.0   4.0  18.1  0.0  0.0   0.0   2019
# 39       Liverpool  ...  13.0   6.0  17.7  0.0  0.0   0.0   2019
# 40   Newcastle Utd  ...   9.0   2.0  20.1  0.0  0.0   0.0   2019
# 41       Tottenham  ...   9.0   1.0  10.2  0.0  0.0   0.0   2019
# 42  Crystal Palace  ...   7.0   1.0  24.8  1.0  0.0   0.0   2019
#
#                     team  venue_code  opp_code
# 1        Manchester City           0        23
# 2        Manchester City           1        18
# 3        Manchester City           1         0
# 4        Manchester City           0        13
# 6        Manchester City           1        20
# ..                   ...         ...       ...
# 38  West Bromwich Albion           0        16
# 39  West Bromwich Albion           1        14
# 40  West Bromwich Albion           0        17
# 41  West Bromwich Albion           1        23
# 42  West Bromwich Albion           0         8
#
# [3800 rows x 29 columns]

# %%
matches["hour"] = matches["time"].str.replace(":.+","",regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["target"] = (matches["result"]=="W").astype("int")

# %%
matches
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L   0   1
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W   5   0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W   5   0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W   1   0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D   0   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 38 2018-04-15  16:00  Premier League  Matchweek 34  Sun  Away      W   1   0
# 39 2018-04-21  12:30  Premier League  Matchweek 35  Sat  Home      D   2   2
# 40 2018-04-28  15:00  Premier League  Matchweek 36  Sat  Away      W   1   0
# 41 2018-05-05  15:00  Premier League  Matchweek 37  Sat  Home      W   1   0
# 42 2018-05-13  15:00  Premier League  Matchweek 38  Sun  Away      L   0   2
#
#           opponent  ...   fk   pk  pkatt  season                  team  \
# 1        Tottenham  ...  1.0  0.0    0.0    2023       Manchester City
# 2     Norwich City  ...  1.0  0.0    0.0    2023       Manchester City
# 3          Arsenal  ...  0.0  0.0    0.0    2023       Manchester City
# 4   Leicester City  ...  0.0  0.0    0.0    2023       Manchester City
# 6      Southampton  ...  1.0  0.0    0.0    2023       Manchester City
# ..             ...  ...  ...  ...    ...     ...                   ...
# 38  Manchester Utd  ...  0.0  0.0    0.0    2019  West Bromwich Albion
# 39       Liverpool  ...  0.0  0.0    0.0    2019  West Bromwich Albion
# 40   Newcastle Utd  ...  0.0  0.0    0.0    2019  West Bromwich Albion
# 41       Tottenham  ...  0.0  0.0    0.0    2019  West Bromwich Albion
# 42  Crystal Palace  ...  1.0  0.0    0.0    2019  West Bromwich Albion
#
#    venue_code opp_code hour  day_code  target
# 1           0       23   16         6       0
# 2           1       18   15         5       1
# 3           1        0   12         5       1
# 4           0       13   15         5       1
# 6           1       20   15         5       0
# ..        ...      ...  ...       ...     ...
# 38          0       16   16         6       1
# 39          1       14   12         5       0
# 40          0       17   15         5       1
# 41          1       23   15         5       1
# 42          0        8   15         6       0
#
# [3800 rows x 32 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50,min_samples_split=10,random_state=1)

# %%
train = matches[matches["date"]<'2022-01-01']

# %%
test = matches[matches["date"]>'2022-01-01']

# %%
predictors = ["venue_code","opp_code","hour","day_code"]

# %%
rf.fit(train[predictors],train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"],preds)

# %%
acc
# Out:
# 0.6056701030927835

# %%
combined = pd.DataFrame(dict(actual=test["target"],prediction=preds))

# %%
pd.crosstab(index=combined["actual"],columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           186  47
# 1           106  49

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"],preds)
# Out:
# 0.5104166666666666

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester United")

# %%
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 0  2021-08-14  12:30  Premier League   Matchweek 1  Sat  Home      W   5   1
# 1  2021-08-22  14:00  Premier League   Matchweek 2  Sun  Away      D   1   1
# 2  2021-08-29  16:30  Premier League   Matchweek 3  Sun  Away      W   1   0
# 3  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Home      W   4   1
# 5  2021-09-19  14:00  Premier League   Matchweek 5  Sun  Away      W   2   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 49 2018-04-18  19:45  Premier League  Matchweek 35  Wed  Away      W   2   0
# 51 2018-04-29  16:30  Premier League  Matchweek 36  Sun  Home      W   2   1
# 52 2018-05-04  20:00  Premier League  Matchweek 37  Fri  Away      L   0   1
# 53 2018-05-10  19:45  Premier League  Matchweek 31  Thu  Away      D   0   0
# 54 2018-05-13  15:00  Premier League  Matchweek 38  Sun  Home      W   1   0
#
#          opponent  ...   fk   pk  pkatt  season               team venue_code  \
# 0    Leeds United  ...  0.0  0.0    0.0    2023  Manchester United          1
# 1     Southampton  ...  1.0  0.0    0.0    2023  Manchester United          0
# 2          Wolves  ...  1.0  0.0    0.0    2023  Manchester United          0
# 3   Newcastle Utd  ...  0.0  0.0    0.0    2023  Manchester United          1
# 5        West Ham  ...  0.0  0.0    0.0    2023  Manchester United          0
# ..            ...  ...  ...  ...    ...     ...                ...        ...
# 49    Bournemouth  ...  1.0  0.0    0.0    2019  Manchester United          0
# 51        Arsenal  ...  1.0  0.0    0.0    2019  Manchester United          1
# 52       Brighton  ...  2.0  0.0    0.0    2019  Manchester United          0
# 53       West Ham  ...  0.0  0.0    0.0    2019  Manchester United          0
# 54        Watford  ...  0.0  0.0    0.0    2019  Manchester United          1
#
#    opp_code hour  day_code  target
# 0        12   12         5       1
# 1        20   14         6       0
# 2        27   16         6       1
# 3        17   15         5       1
# 5        26   14         6       1
# ..      ...  ...       ...     ...
# 49        2   19         2       1
# 51        0   16         6       1
# 52        4   20         4       0
# 53       26   19         3       0
# 54       24   15         6       1
#
# [190 rows x 32 columns]

# %%
def rolling_averages(group,cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf","ga","sh","sot","dist","fk","pk","pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group,cols,new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 4  2017-09-09  17:30  Premier League   Matchweek 4  Sat  Away      D   2   2
# 6  2017-09-17  16:00  Premier League   Matchweek 5  Sun  Home      W   4   0
# 8  2017-09-23  15:00  Premier League   Matchweek 6  Sat  Away      W   1   0
# 10 2017-09-30  15:00  Premier League   Matchweek 7  Sat  Home      W   4   0
# 11 2017-10-14  12:30  Premier League   Matchweek 8  Sat  Away      D   0   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 44 2022-04-23  12:30  Premier League  Matchweek 34  Sat  Away      L   1   3
# 45 2022-04-28  19:45  Premier League  Matchweek 37  Thu  Home      D   1   1
# 46 2022-05-02  20:00  Premier League  Matchweek 35  Mon  Home      W   3   0
# 47 2022-05-07  17:30  Premier League  Matchweek 36  Sat  Away      L   0   4
# 48 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Away      L   0   1
#
#           opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 4       Stoke City  ...         5       0    3.333333    0.000000  19.666667
# 6          Everton  ...         6       1    2.666667    0.666667  18.666667
# 8      Southampton  ...         5       1    2.666667    0.666667  18.000000
# 10  Crystal Palace  ...         5       1    2.333333    0.666667  14.000000
# 11       Liverpool  ...         5       0    3.000000    0.000000  14.000000
# ..             ...  ...       ...     ...         ...         ...        ...
# 44         Arsenal  ...         5       0    1.000000    2.333333  11.333333
# 45         Chelsea  ...         3       0    1.333333    3.000000  11.666667
# 46       Brentford  ...         0       1    0.666667    2.666667   7.000000
# 47        Brighton  ...         5       0    1.666667    1.333333   9.000000
# 48  Crystal Palace  ...         6       0    1.333333    1.666667   9.666667
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4     6.333333    18.733333   0.666667    0.000000       0.333333
# 6     7.333333    18.633333   1.000000    0.000000       0.333333
# 8     6.666667    17.766667   1.333333    0.333333       0.666667
# 10    6.000000    16.933333   1.333333    0.333333       0.333333
# 11    5.666667    15.600000   1.000000    0.333333       0.333333
# ..         ...          ...        ...         ...            ...
# 44    4.666667    18.600000   0.333333    0.000000       0.000000
# 45    5.000000    18.800000   0.333333    0.000000       0.333333
# 46    3.000000    18.333333   0.000000    0.000000       0.333333
# 47    4.000000    18.100000   0.333333    0.333333       0.666667
# 48    4.000000    18.533333   0.666667    0.333333       0.333333
#
# [187 rows x 40 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x,cols,new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 4  2017-09-09  15:00  Premier League   Matchweek 4
#                         6  2017-09-17  13:30  Premier League   Matchweek 5
#                         8  2017-09-25  20:00  Premier League   Matchweek 6
#                         10 2017-10-01  12:00  Premier League   Matchweek 7
#                         11 2017-10-14  17:30  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 37 2022-04-30  15:00  Premier League  Matchweek 35
#                         38 2022-05-07  15:00  Premier League  Matchweek 36
#                         39 2022-05-11  20:15  Premier League  Matchweek 33
#                         40 2022-05-15  14:00  Premier League  Matchweek 37
#                         41 2022-05-22  16:00  Premier League  Matchweek 38
#
#                             day venue result  gf  ga         opponent  ...  \
# team                                                                   ...
# Arsenal                 4   Sat  Home      W   3   0      Bournemouth  ...
#                         6   Sun  Away      D   0   0          Chelsea  ...
#                         8   Mon  Home      W   2   0        West Brom  ...
#                         10  Sun  Home      W   2   0         Brighton  ...
#                         11  Sat  Away      L   1   2          Watford  ...
# ...                         ...   ...    ...  ..  ..              ...  ...
# Wolverhampton Wanderers 37  Sat  Home      L   0   3         Brighton  ...
#                         38  Sat  Away      D   2   2          Chelsea  ...
#                         39  Wed  Home      L   1   5  Manchester City  ...
#                         40  Sun  Home      D   1   1     Norwich City  ...
#                         41  Sun  Away      L   1   3        Liverpool  ...
#
#                             day_code  target  gf_rolling  ga_rolling  \
# team
# Arsenal                 4          5       1    1.333333    2.666667
#                         6          6       0    1.000000    1.666667
#                         8          0       1    1.000000    1.333333
#                         10         6       1    1.666667    0.000000
#                         11         5       0    1.333333    0.000000
# ...                              ...     ...         ...         ...
# Wolverhampton Wanderers 37         5       0    0.666667    1.000000
#                         38         5       0    0.000000    1.666667
#                         39         2       0    0.666667    2.000000
#                         40         6       0    1.000000    3.333333
#                         41         6       0    1.333333    2.666667
#
#                            sh_rolling sot_rolling dist_rolling fk_rolling  \
# team
# Arsenal                 4   17.666667    5.333333    18.133333   0.000000
#                         6   14.333333    5.000000    16.766667   0.333333
#                         8   12.000000    3.666667    16.566667   0.333333
#                         10  14.333333    5.333333    17.400000   1.333333
#                         11  17.000000    5.000000    18.333333   1.666667
# ...                               ...         ...          ...        ...
# Wolverhampton Wanderers 37   8.666667    3.333333    17.400000   0.000000
#                         38   8.666667    2.333333    18.633333   0.333333
#                         39  11.666667    3.000000    17.766667   0.333333
#                         40  10.666667    2.666667    17.066667   0.333333
#                         41  12.666667    3.666667    17.766667   0.333333
#
#                             pk_rolling  pkatt_rolling
# team
# Arsenal                 4     0.000000       0.000000
#                         6     0.000000       0.000000
#                         8     0.000000       0.000000
#                         10    0.333333       0.333333
#                         11    0.333333       0.333333
# ...                                ...            ...
# Wolverhampton Wanderers 37    0.000000       0.000000
#                         38    0.000000       0.000000
#                         39    0.000000       0.000000
#                         40    0.000000       0.000000
#                         41    0.000000       0.000000
#
# [3707 rows x 40 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 4  2017-09-09  15:00  Premier League   Matchweek 4  Sat  Home      W   3   0
# 6  2017-09-17  13:30  Premier League   Matchweek 5  Sun  Away      D   0   0
# 8  2017-09-25  20:00  Premier League   Matchweek 6  Mon  Home      W   2   0
# 10 2017-10-01  12:00  Premier League   Matchweek 7  Sun  Home      W   2   0
# 11 2017-10-14  17:30  Premier League   Matchweek 8  Sat  Away      L   1   2
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 37 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Home      L   0   3
# 38 2022-05-07  15:00  Premier League  Matchweek 36  Sat  Away      D   2   2
# 39 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Home      L   1   5
# 40 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Home      D   1   1
# 41 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Away      L   1   3
#
#            opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 4       Bournemouth  ...         5       1    1.333333    2.666667  17.666667
# 6           Chelsea  ...         6       0    1.000000    1.666667  14.333333
# 8         West Brom  ...         0       1    1.000000    1.333333  12.000000
# 10         Brighton  ...         6       1    1.666667    0.000000  14.333333
# 11          Watford  ...         5       0    1.333333    0.000000  17.000000
# ..              ...  ...       ...     ...         ...         ...        ...
# 37         Brighton  ...         5       0    0.666667    1.000000   8.666667
# 38          Chelsea  ...         5       0    0.000000    1.666667   8.666667
# 39  Manchester City  ...         2       0    0.666667    2.000000  11.666667
# 40     Norwich City  ...         6       0    1.000000    3.333333  10.666667
# 41        Liverpool  ...         6       0    1.333333    2.666667  12.666667
#
#    sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 4     5.333333    18.133333   0.000000    0.000000       0.000000
# 6     5.000000    16.766667   0.333333    0.000000       0.000000
# 8     3.666667    16.566667   0.333333    0.000000       0.000000
# 10    5.333333    17.400000   1.333333    0.333333       0.333333
# 11    5.000000    18.333333   1.666667    0.333333       0.333333
# ..         ...          ...        ...         ...            ...
# 37    3.333333    17.400000   0.000000    0.000000       0.000000
# 38    2.333333    18.633333   0.333333    0.000000       0.000000
# 39    3.000000    17.766667   0.333333    0.000000       0.000000
# 40    2.666667    17.066667   0.333333    0.000000       0.000000
# 41    3.666667    17.766667   0.333333    0.000000       0.000000
#
# [3707 rows x 40 columns]

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result  gf  \
# 0    2017-09-09  15:00  Premier League   Matchweek 4  Sat  Home      W   3
# 1    2017-09-17  13:30  Premier League   Matchweek 5  Sun  Away      D   0
# 2    2017-09-25  20:00  Premier League   Matchweek 6  Mon  Home      W   2
# 3    2017-10-01  12:00  Premier League   Matchweek 7  Sun  Home      W   2
# 4    2017-10-14  17:30  Premier League   Matchweek 8  Sat  Away      L   1
# ...         ...    ...             ...           ...  ...   ...    ...  ..
# 3702 2022-04-30  15:00  Premier League  Matchweek 35  Sat  Home      L   0
# 3703 2022-05-07  15:00  Premier League  Matchweek 36  Sat  Away      D   2
# 3704 2022-05-11  20:15  Premier League  Matchweek 33  Wed  Home      L   1
# 3705 2022-05-15  14:00  Premier League  Matchweek 37  Sun  Home      D   1
# 3706 2022-05-22  16:00  Premier League  Matchweek 38  Sun  Away      L   1
#
#       ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# 0      0      Bournemouth  ...         5       1    1.333333    2.666667
# 1      0          Chelsea  ...         6       0    1.000000    1.666667
# 2      0        West Brom  ...         0       1    1.000000    1.333333
# 3      0         Brighton  ...         6       1    1.666667    0.000000
# 4      2          Watford  ...         5       0    1.333333    0.000000
# ...   ..              ...  ...       ...     ...         ...         ...
# 3702   3         Brighton  ...         5       0    0.666667    1.000000
# 3703   2          Chelsea  ...         5       0    0.000000    1.666667
# 3704   5  Manchester City  ...         2       0    0.666667    2.000000
# 3705   1     Norwich City  ...         6       0    1.000000    3.333333
# 3706   3        Liverpool  ...         6       0    1.333333    2.666667
#
#      sh_rolling sot_rolling dist_rolling fk_rolling  pk_rolling  pkatt_rolling
# 0     17.666667    5.333333    18.133333   0.000000    0.000000       0.000000
# 1     14.333333    5.000000    16.766667   0.333333    0.000000       0.000000
# 2     12.000000    3.666667    16.566667   0.333333    0.000000       0.000000
# 3     14.333333    5.333333    17.400000   1.333333    0.333333       0.333333
# 4     17.000000    5.000000    18.333333   1.666667    0.333333       0.333333
# ...         ...         ...          ...        ...         ...            ...
# 3702   8.666667    3.333333    17.400000   0.000000    0.000000       0.000000
# 3703   8.666667    2.333333    18.633333   0.333333    0.000000       0.000000
# 3704  11.666667    3.000000    17.766667   0.333333    0.000000       0.000000
# 3705  10.666667    2.666667    17.066667   0.333333    0.000000       0.000000
# 3706  12.666667    3.666667    17.766667   0.333333    0.000000       0.000000
#
# [3707 rows x 40 columns]

# %%
def make_predictions(data,predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.6078431372549019

# %%
combined
# Out:
#       actual  predicted
# 169        0          1
# 170        1          1
# 171        1          1
# 172        1          0
# 173        1          0
# ...      ...        ...
# 3702       0          0
# 3703       0          0
# 3704       0          0
# 3705       0          0
# 3706       0          0
#
# [388 rows x 2 columns]

# %%
combined = combined.merge(matches_rolling[["date","team","opponent","result"]], left_index=True,right_index=True)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 169        0          1 2022-01-23                  Arsenal          Burnley
# 170        1          1 2022-02-10                  Arsenal           Wolves
# 171        1          1 2022-02-19                  Arsenal        Brentford
# 172        1          0 2022-02-24                  Arsenal           Wolves
# 173        1          0 2022-03-06                  Arsenal          Watford
# ...      ...        ...        ...                      ...              ...
# 3702       0          0 2022-04-30  Wolverhampton Wanderers         Brighton
# 3703       0          0 2022-05-07  Wolverhampton Wanderers          Chelsea
# 3704       0          0 2022-05-11  Wolverhampton Wanderers  Manchester City
# 3705       0          0 2022-05-15  Wolverhampton Wanderers     Norwich City
# 3706       0          0 2022-05-22  Wolverhampton Wanderers        Liverpool
#
#      result
# 169       D
# 170       W
# 171       W
# 172       W
# 173       W
# ...     ...
# 3702      L
# 3703      D
# 3704      L
# 3705      D
# 3706      L
#
# [388 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self,key:key

map_values = {
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd", 
    "Newcastle United": "Newcastle Utd", 
    "Tottenham Hotspur": "Tottenham",
     "West Ham United": "West Ham", 
     "Wolverhampton Wanderers": "Wolves"
     
} 
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 169        0          1 2022-01-23                  Arsenal          Burnley
# 170        1          1 2022-02-10                  Arsenal           Wolves
# 171        1          1 2022-02-19                  Arsenal        Brentford
# 172        1          0 2022-02-24                  Arsenal           Wolves
# 173        1          0 2022-03-06                  Arsenal          Watford
# ...      ...        ...        ...                      ...              ...
# 3702       0          0 2022-04-30  Wolverhampton Wanderers         Brighton
# 3703       0          0 2022-05-07  Wolverhampton Wanderers          Chelsea
# 3704       0          0 2022-05-11  Wolverhampton Wanderers  Manchester City
# 3705       0          0 2022-05-15  Wolverhampton Wanderers     Norwich City
# 3706       0          0 2022-05-22  Wolverhampton Wanderers        Liverpool
#
#      result new_team
# 169       D  Arsenal
# 170       W  Arsenal
# 171       W  Arsenal
# 172       W  Arsenal
# 173       W  Arsenal
# ...     ...      ...
# 3702      L   Wolves
# 3703      D   Wolves
# 3704      L   Wolves
# 3705      D   Wolves
# 3706      L   Wolves
#
# [388 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on=["date","new_team"],right_on=["date","opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           0            1 2022-01-23                  Arsenal
# 1           1            1 2022-02-10                  Arsenal
# 2           1            1 2022-02-19                  Arsenal
# 3           1            0 2022-02-24                  Arsenal
# 4           1            0 2022-03-06                  Arsenal
# ..        ...          ...        ...                      ...
# 383         0            0 2022-04-30  Wolverhampton Wanderers
# 384         0            0 2022-05-07  Wolverhampton Wanderers
# 385         0            0 2022-05-11  Wolverhampton Wanderers
# 386         0            0 2022-05-15  Wolverhampton Wanderers
# 387         0            0 2022-05-22  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0            Burnley        D    Arsenal         0            0
# 1             Wolves        W    Arsenal         0            0
# 2          Brentford        W    Arsenal         0            0
# 3             Wolves        W    Arsenal         0            0
# 4            Watford        W    Arsenal         0            0
# ..               ...      ...        ...       ...          ...
# 383         Brighton        L     Wolves         1            0
# 384          Chelsea        D     Wolves         0            0
# 385  Manchester City        L     Wolves         1            1
# 386     Norwich City        D     Wolves         0            0
# 387        Liverpool        L     Wolves         1            0
#
#                        team_y opponent_y result_y       new_team_y
# 0                     Burnley    Arsenal        D          Burnley
# 1     Wolverhampton Wanderers    Arsenal        L           Wolves
# 2                   Brentford    Arsenal        L        Brentford
# 3     Wolverhampton Wanderers    Arsenal        L           Wolves
# 4                     Watford    Arsenal        L          Watford
# ..                        ...        ...      ...              ...
# 383  Brighton and Hove Albion     Wolves        W         Brighton
# 384                   Chelsea     Wolves        D          Chelsea
# 385           Manchester City     Wolves        W  Manchester City
# 386              Norwich City     Wolves        D     Norwich City
# 387                 Liverpool     Wolves        W        Liverpool
#
# [388 rows x 13 columns]

# %%
merged[(merged["predicted_x"]==1)&(merged["predicted_y"]==0)]["actual_x"].value_counts()
# Out:
# 1    54
# 0    28
# Name: actual_x, dtype: int64

# %%
54/(54+28)
# Out:
# 0.6585365853658537
